# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/RASIL-RISAM/-covid-research-/main/all_training.csv")
df
# Out:
#              Unnamed: 0  Sex   Age    CA     CK   CREA    ALP    GGT    GLU  \
# 0     A00345_2020-03-25  1.0  82.0  2.09    NaN  1.150   95.0   40.0   78.0
# 1     A00791_2020-03-19  1.0  51.0  1.97  237.0  0.970   54.0   98.0   98.0
# 2     A00741_2020-03-04  1.0  58.0  2.11    NaN  1.000   80.0  147.0  106.0
# 3     A00605_2020-04-15  0.0  82.0  2.27  138.0  0.755  123.5  176.5  106.0
# 4     A00417_2020-02-24  1.0  79.0  2.07   73.0  1.810   62.0   36.5   96.0
# ...                 ...  ...   ...   ...    ...    ...    ...    ...    ...
# 1731                 49  0.0   NaN  2.38   40.0  0.800   68.0    9.0  128.0
# 1732                 50  0.0   NaN  2.36    NaN  0.960   79.0   35.0  107.0
# 1733                 51  1.0   NaN  2.28    NaN  1.420    NaN    NaN  136.0
# 1734                 52  1.0   NaN  2.40  124.0  0.950   48.0   44.0   95.0
# 1735                 53  1.0   NaN  2.14    NaN  1.040    NaN    NaN  179.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1736 non-null   object
#  1   Sex         1736 non-null   float64
#  2   Age         1682 non-null   float64
#  3   CA          1643 non-null   float64
#  4   CK          704 non-null    float64
#  5   CREA        1662 non-null   float64
#  6   ALP         1262 non-null   float64
#  7   GGT         1300 non-null   float64
#  8   GLU         1638 non-null   float64
#  9   AST         1638 non-null   float64
#  10  ALT         1640 non-null   float64
#  11  LDH         1433 non-null   float64
#  12  PCR         1639 non-null   float64
#  13  KAL         1656 non-null   float64
#  14  NAT         1663 non-null   float64
#  15  UREA        1060 non-null   float64
#  16  WBC         1673 non-null   float64
#  17  RBC         1673 non-null   float64
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0    1736
# Sex              3
# Age            101
# CA             229
# CK             327
# CREA           422
# ALP            256
# GGT            291
# GLU            321
# AST            280
# ALT            263
# LDH            607
# PCR           1055
# KAL            436
# NAT            379
# UREA           243
# WBC            440
# RBC            554
# HGB            255
# HCT            488
# MCV            541
# MCH            325
# MCHC           219
# PLT1           622
# NE             645
# LY             559
# MO             305
# EO             151
# BA              69
# NET            333
# LYT            152
# MOT            120
# EOT             66
# BAT             43
# Suspect          3
# target           2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Sex              0
# Age             54
# CA              93
# CK            1032
# CREA            74
# ALP            474
# GGT            436
# GLU             98
# AST             98
# ALT             96
# LDH            303
# PCR             97
# KAL             80
# NAT             73
# UREA           676
# WBC             63
# RBC             63
# HGB             63
# HCT             63
# MCV             63
# MCH             63
# MCHC            63
# PLT1            63
# NE             362
# LY             362
# MO             362
# EO             362
# BA             362
# NET            362
# LYT            362
# MOT            362
# EOT            362
# BAT            362
# Suspect          0
# target           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sex', 'Age', 'CA', 'CK', 'CREA', 'ALP', 'GGT', 'GLU',
#        'AST', 'ALT', 'LDH', 'PCR', 'KAL', 'NAT', 'UREA', 'WBC', 'RBC', 'HGB',
#        'HCT', 'MCV', 'MCH', 'MCHC', 'PLT1', 'NE', 'LY', 'MO', 'EO', 'BA',
#        'NET', 'LYT', 'MOT', 'EOT', 'BAT', 'Suspect', 'target'],
#       dtype='object')

# %%
df.shape
# Out:
# (1736, 36)

# %%
df = df.dropna()
df.shape
# Out:
# (324, 36)

# %%
normal_ranges = {
    'CK': (5, 25),  # Normal range for CK
    'CREA': (0.74, 1.35),  # Normal range for CREA in males
    'GGT': (7, 47),  # Normal range for GGT in males
}

# %%
for param, (lower, upper) in normal_ranges.items():
    df[f'{param}_Normal'] = ((df[param] >= lower) & (df[param] <= upper)).astype(int)

# Calculate ratios or differences between pairs of parameters
df['CK_CREARatio'] = df['CK'] / df['CREA']
df['CREA_GLURatio'] = df['CREA'] / df['GLU']
# Out:
# <ipython-input-10-918293c1303e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{param}_Normal'] = ((df[param] >= lower) & (df[param] <= upper)).astype(int)
# <ipython-input-10-918293c1303e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{param}_Normal'] = ((df[param] >= lower) & (df[param] <= upper)).astype(int)
# <ipython-input-10-918293c1303e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.head()
# Out:
#            Unnamed: 0  Sex   Age    CA     CK      CREA    ALP    GGT  \
# 3   A00605_2020-04-15  0.0  82.0  2.27  138.0  0.755000  123.5  176.5
# 4   A00417_2020-02-24  1.0  79.0  2.07   73.0  1.810000   62.0   36.5
# 5   A01643_2020-04-01  1.0  84.0  2.06  115.0  1.283333   75.0   75.0
# 12  A01477_2020-04-21  0.0  53.0  2.36   45.5  0.593333   62.0   21.5
# 13  A01399_2020-03-22  0.0  76.0  2.20  349.0  2.420000  159.5  147.0
#
#            GLU     AST  ...   MOT   EOT  BAT  Suspect  target  CK_Normal  \
# 3   106.000000   114.0  ...  0.70  0.10  0.1      0.5       0          0
# 4    96.000000    28.0  ...  0.10  0.10  0.0      1.0       0          0
# 5    95.500000    40.5  ...  0.25  0.05  0.0      0.0       1          0
# 12   91.666667    36.0  ...  0.60  0.05  0.0      1.0       0          0
# 13  640.000000  1018.5  ...  1.25  0.00  0.0      0.5       1          0
#
#     CREA_Normal  GGT_Normal  CK_CREARatio  CREA_GLURatio
# ...

# %%
df.describe().T
# Out:
#                count        mean         std         min         25%  \
# Sex            324.0    0.611111    0.488252    0.000000    0.000000
# Age            324.0   63.157407   16.911624   17.000000   50.000000
# CA             324.0    2.151962    0.169157    1.363333    2.053750
# CK             324.0  230.195542  500.925759   10.000000   54.000000
# CREA           324.0    1.305642    1.180403    0.430000    0.770000
# ALP            324.0   94.088220   82.791176   23.000000   58.000000
# GGT            324.0   81.881481  159.184352    7.000000   22.000000
# GLU            324.0  128.047479   71.970011   65.500000   94.500000
# AST            324.0   58.135545   74.786616   12.000000   25.000000
# ALT            324.0   48.358333   56.836213    8.000000   20.875000
# LDH            324.0  362.996914  191.368940  104.000000  235.666667
# PCR            324.0   83.634372   87.145969    0.300000   14.200000
# KAL            324.0    4.246415    0.527639    2.560000    3.942500
# ...

# %%
x=df[['Age','CK_CREARatio','CREA_GLURatio','ALP','AST', 'ALT','LDH','RBC',
       'MCV','MO','BA','EOT']]
x
# Out:
#        Age  CK_CREARatio  CREA_GLURatio    ALP     AST    ALT    LDH  \
# 3     82.0    182.781457       0.007123  123.5   114.0   63.0  281.0
# 4     79.0     40.331492       0.018854   62.0    28.0   38.5  264.0
# 5     84.0     89.610390       0.013438   75.0    40.5   27.0  364.5
# 12    53.0     76.685393       0.006473   62.0    36.0   35.5  269.5
# 13    76.0    144.214876       0.003781  159.5  1018.5  559.5  694.0
# ...    ...           ...            ...    ...     ...    ...    ...
# 1606  52.0    169.230769       0.003714   85.0    27.0   34.0  196.0
# 1619  80.0     72.058824       0.006018   95.0    22.0   15.5  319.0
# 1644  68.0     27.616279       0.008843   58.0    12.2   16.4  185.0
# 1650  79.0     59.375682       0.005473   44.0    46.3   33.7  422.3
# 1678  58.0    107.239819       0.007342   42.0    21.0   35.0  242.5
#
#            RBC        MCV     MO    BA    EOT
# 3     5.000000  84.600000   9.50  0.90  0.100
# ...

# %%
y=df[['target']]

# %%
for col in x:
    print(col)
    print('Skew :', round(x[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    x[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x)
    plt.show()
# Out:
# Age
# Skew : -0.29
# CK_CREARatio
# Skew : 10.67
# CREA_GLURatio
# Skew : 6.28
# ALP
# Skew : 4.58
# AST
# Skew : 7.61
# ALT
# Skew : 4.86
# LDH
# Skew : 2.3
# RBC
# Skew : -0.3
# MCV
# Skew : -0.72
# MO
# Skew : 1.31
# BA
# Skew : 1.46
# EOT
# Skew : 5.66

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.20, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
st_x= MinMaxScaler()
x_train= st_x.fit_transform(x_train)
x_test= st_x.transform(x_test)

# %%
x_train
# Out:
# array([[7.43902439e-01, 1.43696578e-02, 2.21437687e-01, ...,
#         1.32867133e-01, 1.78571429e-01, 0.00000000e+00],
#        [8.29268293e-01, 7.70225837e-04, 1.05998430e-01, ...,
#         5.66433566e-01, 7.14285714e-02, 6.89655172e-02],
#        [5.12195122e-01, 7.79238938e-03, 4.80938312e-02, ...,
#         8.39160839e-02, 1.42857143e-01, 0.00000000e+00],
#        ...,
#        [7.56097561e-01, 3.86023305e-03, 3.32868855e-01, ...,
#         5.20104895e-01, 3.21428571e-01, 1.72413793e-02],
#        [5.60975610e-01, 1.14896662e-02, 5.73627976e-03, ...,
#         1.85314685e-01, 1.07142857e-01, 0.00000000e+00],
#        [6.95121951e-01, 4.86205890e-03, 9.30207003e-02, ...,
#         1.67832168e-01, 2.14285714e-01, 0.00000000e+00]])

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier= KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
y_pred= classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.78      0.69        23
#            1       0.86      0.74      0.79        42
#
#     accuracy                           0.75        65
#    macro avg       0.74      0.76      0.74        65
# weighted avg       0.78      0.75      0.76        65

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[18  5]
#  [11 31]]

# %%
 from sklearn.metrics import ConfusionMatrixDisplay

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=classifier.classes_)
disp.plot()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# Train the classifier
clf.fit(x_train, y_train)

# Get feature importances
feature_importances = clf.feature_importances_

# Create a DataFrame to display feature importances
feature_importance_df = pd.DataFrame({'Feature': x.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print feature importances
print(feature_importance_df)
# Out:
# <ipython-input-25-f4b67926a9cd>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
#           Feature  Importance
# 6             LDH    0.198188
# 4             AST    0.141888
# 10             BA    0.085310
# 5             ALT    0.082659
# 7             RBC    0.082135
# 11            EOT    0.075761
# 0             Age    0.075734
# 3             ALP    0.060227
# 9              MO    0.054267
# 1    CK_CREARatio    0.053948
# 8             MCV    0.046954
# 2   CREA_GLURatio    0.042928

# %%
from sklearn.model_selection import GridSearchCV

# Define a range of values for n_neighbors to be tested
param_grid = {'n_neighbors': np.arange(1, 21)}

# Initialize the KNN classifier
knn = KNeighborsClassifier()

# Perform grid search with cross-validation
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Evaluate the model with the best hyperparameters on the test set
best_knn = grid_search.best_estimator_
y_pred = best_knn.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
# Print classification report and confusion matrix
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.83      0.76        23
#            1       0.89      0.81      0.85        42
#
#     accuracy                           0.82        65
#    macro avg       0.80      0.82      0.81        65
# weighted avg       0.83      0.82      0.82        65
#
# Confusion Matrix:
# [[19  4]
#  [ 8 34]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
st_x= MinMaxScaler()
x_train= st_x.fit_transform(x_train)
x_test= st_x.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
classifier2 = GaussianNB()
classifier2.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
y_pred2 = classifier2.predict(x_test)

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred2)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71        27
#            1       0.87      0.83      0.85        54
#
#     accuracy                           0.80        81
#    macro avg       0.78      0.79      0.78        81
# weighted avg       0.81      0.80      0.80        81

# %%
from sklearn.metrics import confusion_matrix
cm2= confusion_matrix(y_test, y_pred2)
print(cm2)
# Out:
# [[20  7]
#  [ 9 45]]

# %%
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm2,display_labels=classifier2.classes_)
disp2.plot()
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

# Initialize Gaussian Naive Bayes classifier
gnb = GaussianNB()

# Define parameters grid (no specific parameters for GaussianNB)
param_grid = {}

# Perform grid search with cross-validation
grid_search = GridSearchCV(gnb, param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)

# Get the best estimator
best_gnb = grid_search.best_estimator_

# Print the best parameters
print("Best Parameters:", grid_search.best_params_)

# Evaluate the best model on the test set
y_pred = best_gnb.predict(x_test)

# Print classification report and confusion matrix
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Best Parameters: {}
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71        27
#            1       0.87      0.83      0.85        54
#
#     accuracy                           0.80        81
#    macro avg       0.78      0.79      0.78        81
# weighted avg       0.81      0.80      0.80        81
#
# Confusion Matrix:
# [[20  7]
#  [ 9 45]]
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
st_x= MinMaxScaler()
x_train= st_x.fit_transform(x_train)
x_test= st_x.transform(x_test)

# %%
clf3 = AdaBoostClassifier(n_estimators=100, algorithm="SAMME", random_state=0)

# %%
clf3.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostClassifier(algorithm='SAMME', n_estimators=100, random_state=0)

# %%
y_pred3=clf3.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm3= confusion_matrix(y_test, y_pred3)
print(cm3)
# Out:
# [[22  5]
#  [ 9 45]]

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred3)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.81      0.76        27
#            1       0.90      0.83      0.87        54
#
#     accuracy                           0.83        81
#    macro avg       0.80      0.82      0.81        81
# weighted avg       0.84      0.83      0.83        81

# %%
disp3 = ConfusionMatrixDisplay(confusion_matrix=cm3,display_labels=clf3.classes_)
disp3.plot()
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/RASIL-RISAM/-covid-research-/main/all_training.csv")
df
# Out:
#              Unnamed: 0  Sex   Age    CA     CK   CREA    ALP    GGT    GLU  \
# 0     A00345_2020-03-25  1.0  82.0  2.09    NaN  1.150   95.0   40.0   78.0
# 1     A00791_2020-03-19  1.0  51.0  1.97  237.0  0.970   54.0   98.0   98.0
# 2     A00741_2020-03-04  1.0  58.0  2.11    NaN  1.000   80.0  147.0  106.0
# 3     A00605_2020-04-15  0.0  82.0  2.27  138.0  0.755  123.5  176.5  106.0
# 4     A00417_2020-02-24  1.0  79.0  2.07   73.0  1.810   62.0   36.5   96.0
# ...                 ...  ...   ...   ...    ...    ...    ...    ...    ...
# 1731                 49  0.0   NaN  2.38   40.0  0.800   68.0    9.0  128.0
# 1732                 50  0.0   NaN  2.36    NaN  0.960   79.0   35.0  107.0
# 1733                 51  1.0   NaN  2.28    NaN  1.420    NaN    NaN  136.0
# 1734                 52  1.0   NaN  2.40  124.0  0.950   48.0   44.0   95.0
# 1735                 53  1.0   NaN  2.14    NaN  1.040    NaN    NaN  179.0
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sex', 'Age', 'CA', 'CK', 'CREA', 'ALP', 'GGT', 'GLU',
#        'AST', 'ALT', 'LDH', 'PCR', 'KAL', 'NAT', 'UREA', 'WBC', 'RBC', 'HGB',
#        'HCT', 'MCV', 'MCH', 'MCHC', 'PLT1', 'NE', 'LY', 'MO', 'EO', 'BA',
#        'NET', 'LYT', 'MOT', 'EOT', 'BAT', 'Suspect', 'target'],
#       dtype='object')

# %%
df.shape
# Out:
# (1736, 36)

# %%
df = df.dropna()
df.shape
# Out:
# (324, 36)

# %%
normal_ranges = {
    'CK': (5, 25),  # Normal range for CK
    'CREA': (0.74, 1.35),  # Normal range for CREA in males
    'GGT': (7, 47),  # Normal range for GGT in males
}

# %%
for param, (lower, upper) in normal_ranges.items():
    df[f'{param}_Normal'] = ((df[param] >= lower) & (df[param] <= upper)).astype(int)

# Calculate ratios or differences between pairs of parameters
df['CK_CREARatio'] = df['CK'] / df['CREA']
df['CREA_GLURatio'] = df['CREA'] / df['GLU']
# Out:
# <ipython-input-51-918293c1303e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{param}_Normal'] = ((df[param] >= lower) & (df[param] <= upper)).astype(int)
# <ipython-input-51-918293c1303e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{param}_Normal'] = ((df[param] >= lower) & (df[param] <= upper)).astype(int)
# <ipython-input-51-918293c1303e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.head()
# Out:
#            Unnamed: 0  Sex   Age    CA     CK      CREA    ALP    GGT  \
# 3   A00605_2020-04-15  0.0  82.0  2.27  138.0  0.755000  123.5  176.5
# 4   A00417_2020-02-24  1.0  79.0  2.07   73.0  1.810000   62.0   36.5
# 5   A01643_2020-04-01  1.0  84.0  2.06  115.0  1.283333   75.0   75.0
# 12  A01477_2020-04-21  0.0  53.0  2.36   45.5  0.593333   62.0   21.5
# 13  A01399_2020-03-22  0.0  76.0  2.20  349.0  2.420000  159.5  147.0
#
#            GLU     AST  ...   MOT   EOT  BAT  Suspect  target  CK_Normal  \
# 3   106.000000   114.0  ...  0.70  0.10  0.1      0.5       0          0
# 4    96.000000    28.0  ...  0.10  0.10  0.0      1.0       0          0
# 5    95.500000    40.5  ...  0.25  0.05  0.0      0.0       1          0
# 12   91.666667    36.0  ...  0.60  0.05  0.0      1.0       0          0
# 13  640.000000  1018.5  ...  1.25  0.00  0.0      0.5       1          0
#
#     CREA_Normal  GGT_Normal  CK_CREARatio  CREA_GLURatio
# ...

# %%
x=df[['Age','CK_CREARatio','CREA_GLURatio','ALP','AST', 'ALT','LDH','RBC',
       'MCV','MO','BA','EOT']]
x
# Out:
#        Age  CK_CREARatio  CREA_GLURatio    ALP     AST    ALT    LDH  \
# 3     82.0    182.781457       0.007123  123.5   114.0   63.0  281.0
# 4     79.0     40.331492       0.018854   62.0    28.0   38.5  264.0
# 5     84.0     89.610390       0.013438   75.0    40.5   27.0  364.5
# 12    53.0     76.685393       0.006473   62.0    36.0   35.5  269.5
# 13    76.0    144.214876       0.003781  159.5  1018.5  559.5  694.0
# ...    ...           ...            ...    ...     ...    ...    ...
# 1606  52.0    169.230769       0.003714   85.0    27.0   34.0  196.0
# 1619  80.0     72.058824       0.006018   95.0    22.0   15.5  319.0
# 1644  68.0     27.616279       0.008843   58.0    12.2   16.4  185.0
# 1650  79.0     59.375682       0.005473   44.0    46.3   33.7  422.3
# 1678  58.0    107.239819       0.007342   42.0    21.0   35.0  242.5
#
#            RBC        MCV     MO    BA    EOT
# 3     5.000000  84.600000   9.50  0.90  0.100
# ...

# %%
y=df[['target']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.20, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
st_x= MinMaxScaler()
x_train= st_x.fit_transform(x_train)
x_test= st_x.transform(x_test)

# %%
x_train
# Out:
# array([[7.43902439e-01, 1.43696578e-02, 2.21437687e-01, ...,
#         1.32867133e-01, 1.78571429e-01, 0.00000000e+00],
#        [8.29268293e-01, 7.70225837e-04, 1.05998430e-01, ...,
#         5.66433566e-01, 7.14285714e-02, 6.89655172e-02],
#        [5.12195122e-01, 7.79238938e-03, 4.80938312e-02, ...,
#         8.39160839e-02, 1.42857143e-01, 0.00000000e+00],
#        ...,
#        [7.56097561e-01, 3.86023305e-03, 3.32868855e-01, ...,
#         5.20104895e-01, 3.21428571e-01, 1.72413793e-02],
#        [5.60975610e-01, 1.14896662e-02, 5.73627976e-03, ...,
#         1.85314685e-01, 1.07142857e-01, 0.00000000e+00],
#        [6.95121951e-01, 4.86205890e-03, 9.30207003e-02, ...,
#         1.67832168e-01, 2.14285714e-01, 0.00000000e+00]])

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier= KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
y_pred= classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.78      0.69        23
#            1       0.86      0.74      0.79        42
#
#     accuracy                           0.75        65
#    macro avg       0.74      0.76      0.74        65
# weighted avg       0.78      0.75      0.76        65

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[18  5]
#  [11 31]]

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# Train the classifier
clf.fit(x_train, y_train)

# Get feature importances
feature_importances = clf.feature_importances_

# Create a DataFrame to display feature importances
feature_importance_df = pd.DataFrame({'Feature': x.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print feature importances
print(feature_importance_df)
# Out:
# <ipython-input-62-f4b67926a9cd>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
#           Feature  Importance
# 6             LDH    0.196873
# 4             AST    0.141556
# 10             BA    0.088443
# 7             RBC    0.084457
# 5             ALT    0.083408
# 0             Age    0.070572
# 3             ALP    0.063550
# 9              MO    0.062086
# 11            EOT    0.061508
# 1    CK_CREARatio    0.052220
# 8             MCV    0.049239
# 2   CREA_GLURatio    0.046089

# %%
from sklearn.model_selection import GridSearchCV

# Define a range of values for n_neighbors to be tested
param_grid = {'n_neighbors': np.arange(1, 21)}

# Initialize the KNN classifier
knn = KNeighborsClassifier()

# Perform grid search with cross-validation
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Evaluate the model with the best hyperparameters on the test set
best_knn = grid_search.best_estimator_
y_pred = best_knn.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
# Print classification report and confusion matrix
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.83      0.76        23
#            1       0.89      0.81      0.85        42
#
#     accuracy                           0.82        65
#    macro avg       0.80      0.82      0.81        65
# weighted avg       0.83      0.82      0.82        65
#
# Confusion Matrix:
# [[19  4]
#  [ 8 34]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
st_x= MinMaxScaler()
x_train= st_x.fit_transform(x_train)
x_test= st_x.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
classifier2 = GaussianNB()
classifier2.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
y_pred2 = classifier2.predict(x_test)

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred2)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71        27
#            1       0.87      0.83      0.85        54
#
#     accuracy                           0.80        81
#    macro avg       0.78      0.79      0.78        81
# weighted avg       0.81      0.80      0.80        81

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred2)
print(cm)
# Out:
# [[20  7]
#  [ 9 45]]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

# Initialize Gaussian Naive Bayes classifier
gnb = GaussianNB()

# Define parameters grid (no specific parameters for GaussianNB)
param_grid = {}

# Perform grid search with cross-validation
grid_search = GridSearchCV(gnb, param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)

# Get the best estimator
best_gnb = grid_search.best_estimator_

# Print the best parameters
print("Best Parameters:", grid_search.best_params_)

# Evaluate the best model on the test set
y_pred = best_gnb.predict(x_test)

# Print classification report and confusion matrix
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Parameters: {}
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71        27
#            1       0.87      0.83      0.85        54
#
#     accuracy                           0.80        81
#    macro avg       0.78      0.79      0.78        81
# weighted avg       0.81      0.80      0.80        81
#
# Confusion Matrix:
# [[20  7]
#  [ 9 45]]
# ...
